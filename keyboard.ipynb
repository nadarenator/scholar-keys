# %%
import pandas as pd
from copy import deepcopy
import json
from optimizer import keyboard

# %%
#THIS CELL NEED ONLY BE EXECUTED THE FIRST TIME
# arxiv_data = [] #create empty list
# for line in open('arxiv/arxiv-metadata-oai-snapshot.json', 'r'): #open file  line by line
#     arxiv_data.append(json.loads(line)) #append data to the inittially created list
# df = pd.DataFrame.from_records(arxiv_data) #convert data to dataframe
# abstracts = df['abstract']
# abstracts = abstracts.drop_duplicates()
# abstracts = abstracts.str.lower().str.replace(r'\s+', '')
# abstracts = abstracts.apply(lambda x: str(x) if isinstance(x, str) else None).dropna()
# abstracts = abstracts.astype(str)
# print(abstracts.describe())
#abstracts.to_csv('abstracts.csv', index = False)

# %%
abstracts = pd.read_csv('abstracts.csv', header = None).squeeze("columns")
dataset = abstracts

# %%
k = keyboard()
k.optimize_counts(dataset)
# Out:
# Initial key config:
# ['q', 'w', 'e', 'r', 't', 'y', 'u', 'i', 'o', 'p']
# ['a', 's', 'd', 'f', 'g', 'h', 'j', 'k', 'l']
# ['z', 'x', 'c', 'v', 'b', 'n', 'm']
#
# Initial loss:  1349587859.6862779
# Count optimized key config:
# ['c', 'h', 'd', 'm', 'q', 'z', 'u', 'p', 'f', 'g']
# ['e', 't', 'i', 'a', 'r', 'l', 'o', 'n', 's']
# ['y', 'b', 'w', 'v', 'j', 'x', 'k']
#
# Count optimized loss:  718023260.9802861

# %%
k1 = deepcopy(k)
k1.batch_optimize_heuristic(dataset)
# Out:
# Number of Batches:  100
# Processing Batch:  1
# Initial Key Config:
# ['c', 'h', 'd', 'm', 'q', 'z', 'u', 'p', 'f', 'g']
# ['e', 't', 'i', 'a', 'r', 'l', 'o', 'n', 's']
# ['y', 'b', 'w', 'v', 'j', 'x', 'k']
#
# Loss:  6167069.3299966715
# Epoch:  1
# [########################################] | 100% Completed | 12m 9ss
# Transition Made:  [11 13]
# Current Key Config:
# ['c', 'h', 'd', 'm', 'q', 'z', 'u', 'p', 'f', 'g']
# ['e', 'a', 'i', 't', 'r', 'l', 'o', 'n', 's']
# ['y', 'b', 'w', 'v', 'j', 'x', 'k']
#
# Loss:  6061335.12999728
# Epoch:  2
# [########################################] | 100% Completed | 11m 52s
# Transition Made:  [2 6]
# Current Key Config:
# ['c', 'h', 'u', 'm', 'q', 'z', 'd', 'p', 'f', 'g']
# ['e', 'a', 'i', 't', 'r', 'l', 'o', 'n', 's']
# ['y', 'b', 'w', 'v', 'j', 'x', 'k']
#
# Loss:  6031737.729997445
# Epoch:  3
# [########################################] | 100% Completed | 11m 57s
# Transition Made:  [13 17]
# Current Key Config:
# ['c', 'h', 'u', 'm', 'q', 'z', 'd', 'p', 'f', 'g']
# ['e', 'a', 'i', 'n', 'r', 'l', 'o', 't', 's']
# ['y', 'b', 'w', 'v', 'j', 'x', 'k']
#
# Loss:  6010392.329997562
# Epoch:  4
# [########################################] | 100% Completed | 11m 53s
# Transition Made:  [0 9]
# Current Key Config:
# ['g', 'h', 'u', 'm', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'a', 'i', 'n', 'r', 'l', 'o', 't', 's']
# ['y', 'b', 'w', 'v', 'j', 'x', 'k']
#
# Loss:  5989420.729997674
# Epoch:  5
# [########################################] | 100% Completed | 12m 9ss
# Transition Made:  [11 18]
# Current Key Config:
# ['g', 'h', 'u', 'm', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 's', 'i', 'n', 'r', 'l', 'o', 't', 'a']
# ['y', 'b', 'w', 'v', 'j', 'x', 'k']
#
# Loss:  5974359.529997755
# Epoch:  6
# [########################################] | 100% Completed | 12m 0ss
# Transition Made:  [11 16]
# Current Key Config:
# ['g', 'h', 'u', 'm', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 'i', 'n', 'r', 'l', 's', 't', 'a']
# ['y', 'b', 'w', 'v', 'j', 'x', 'k']
#
# Loss:  5964351.329997808
# Epoch:  7
# [########################################] | 100% Completed | 12m 2ss
# Transition Made:  [14 15]
# Current Key Config:
# ['g', 'h', 'u', 'm', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 'i', 'n', 'l', 'r', 's', 't', 'a']
# ['y', 'b', 'w', 'v', 'j', 'x', 'k']
#
# Loss:  5960457.72999783
# Epoch:  8
# [########################################] | 100% Completed | 11m 57s
# Transition Made:  [0 2]
# Current Key Config:
# ['u', 'h', 'g', 'm', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 'i', 'n', 'l', 'r', 's', 't', 'a']
# ['y', 'b', 'w', 'v', 'j', 'x', 'k']
#
# Loss:  5957654.729997845
# Epoch:  9
# [########################################] | 100% Completed | 11m 54s
# Transition Made:  [12 17]
# Current Key Config:
# ['u', 'h', 'g', 'm', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'b', 'w', 'v', 'j', 'x', 'k']
#
# Loss:  5950965.12999788
# Epoch:  10
# [########################################] | 100% Completed | 12m 14s
# Transition Made:  [21 22]
# Current Key Config:
# ['u', 'h', 'g', 'm', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'b', 'v', 'w', 'j', 'x', 'k']
#
# Loss:  5945108.129997911
# Epoch:  11
# [########################################] | 100% Completed | 11m 58s
# Transition Made:  [20 21]
# Current Key Config:
# ['u', 'h', 'g', 'm', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'v', 'b', 'w', 'j', 'x', 'k']
#
# Loss:  5943230.929997921
# Epoch:  12
# [########################################] | 100% Completed | 12m 2ss
# Transition Made:  [20 25]
# Current Key Config:
# ['u', 'h', 'g', 'm', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  5939048.729997943
# Epoch:  13
# [########################################] | 100% Completed | 11m 58s
# Transition Made:  [1 6]
# Current Key Config:
# ['u', 'd', 'g', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  5938038.329997949
# Epoch:  14
# [########################################] | 100% Completed | 12m 0ss
# Transition Made:  [1 2]
# Current Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  5936672.329997956
# Epoch:  15
# [########################################] | 100% Completed | 12m 1ss
# Local Minima of loss reached.
# Processing Batch:  2
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  5780817.26999802
# Epoch:  1
# [########################################] | 100% Completed | 11m 45s
# Local Minima of loss reached.
# Processing Batch:  3
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  5944965.21999795
# Epoch:  1
# [########################################] | 100% Completed | 11m 59s
# Local Minima of loss reached.
# Processing Batch:  4
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6005271.339997924
# Epoch:  1
# [########################################] | 100% Completed | 12m 18s
# Local Minima of loss reached.
# Processing Batch:  5
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6028217.839997903
# Epoch:  1
# [########################################] | 100% Completed | 12m 29s
# Local Minima of loss reached.
# Processing Batch:  6
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6020070.549997915
# Epoch:  1
# [########################################] | 100% Completed | 12m 19s
# Local Minima of loss reached.
# Processing Batch:  7
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6147098.0199978575
# Epoch:  1
# [########################################] | 100% Completed | 12m 20s
# Local Minima of loss reached.
# Processing Batch:  8
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6157868.609997844
# Epoch:  1
# [########################################] | 100% Completed | 12m 20s
# Local Minima of loss reached.
# Processing Batch:  9
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6333071.4099977445
# Epoch:  1
# [########################################] | 100% Completed | 12m 44s
# Local Minima of loss reached.
# Processing Batch:  10
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6345194.219997747
# Epoch:  1
# [########################################] | 100% Completed | 12m 56s
# Local Minima of loss reached.
# Processing Batch:  11
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6252824.999997793
# Epoch:  1
# [########################################] | 100% Completed | 12m 36s
# Local Minima of loss reached.
# Processing Batch:  12
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6336825.399997754
# Epoch:  1
# [########################################] | 100% Completed | 12m 42s
# Local Minima of loss reached.
# Processing Batch:  13
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6414447.48999768
# Epoch:  1
# [########################################] | 100% Completed | 12m 49s
# Local Minima of loss reached.
# Processing Batch:  14
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6392846.059997695
# Epoch:  1
# [########################################] | 100% Completed | 12m 45s
# Local Minima of loss reached.
# Processing Batch:  15
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6415459.479997676
# Epoch:  1
# [########################################] | 100% Completed | 12m 53s
# Local Minima of loss reached.
# Processing Batch:  16
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6505813.849997615
# Epoch:  1
# [########################################] | 100% Completed | 13m 0ss
# Local Minima of loss reached.
# Processing Batch:  17
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6592309.0999975195
# Epoch:  1
# [########################################] | 100% Completed | 13m 5ss
# Local Minima of loss reached.
# Processing Batch:  18
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6533366.929997573
# Epoch:  1
# [########################################] | 100% Completed | 12m 58s
# Local Minima of loss reached.
# Processing Batch:  19
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6511503.979997601
# Epoch:  1
# [########################################] | 100% Completed | 13m 3ss
# Local Minima of loss reached.
# Processing Batch:  20
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6592864.439997517
# Epoch:  1
# [########################################] | 100% Completed | 13m 18s
# Local Minima of loss reached.
# Processing Batch:  21
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6690835.399997409
# Epoch:  1
# [########################################] | 100% Completed | 13m 24s
# Local Minima of loss reached.
# Processing Batch:  22
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6622250.4799975045
# Epoch:  1
# [########################################] | 100% Completed | 13m 10s
# Local Minima of loss reached.
# Processing Batch:  23
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6707585.399997368
# Epoch:  1
# [########################################] | 100% Completed | 13m 12s
# Local Minima of loss reached.
# Processing Batch:  24
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6761700.499997331
# Epoch:  1
# [########################################] | 100% Completed | 13m 25s
# Local Minima of loss reached.
# Processing Batch:  25
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6877178.029997179
# Epoch:  1
# [########################################] | 100% Completed | 13m 49s
# Local Minima of loss reached.
# Processing Batch:  26
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6841281.499997228
# Epoch:  1
# [########################################] | 100% Completed | 13m 49s
# Local Minima of loss reached.
# Processing Batch:  27
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6800270.249997296
# Epoch:  1
# [########################################] | 100% Completed | 13m 33s
# Local Minima of loss reached.
# Processing Batch:  28
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6864576.289997211
# Epoch:  1
# [########################################] | 100% Completed | 13m 44s
# Local Minima of loss reached.
# Processing Batch:  29
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6948064.149997091
# Epoch:  1
# [########################################] | 100% Completed | 13m 51s
# Local Minima of loss reached.
# Processing Batch:  30
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6944275.769997098
# Epoch:  1
# [########################################] | 100% Completed | 13m 53s
# Local Minima of loss reached.
# Processing Batch:  31
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6979728.529997034
# Epoch:  1
# [########################################] | 100% Completed | 13m 54s
# Local Minima of loss reached.
# Processing Batch:  32
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6999291.799997018
# Epoch:  1
# [########################################] | 100% Completed | 14m 0ss
# Local Minima of loss reached.
# Processing Batch:  33
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7043482.369996959
# Epoch:  1
# [########################################] | 100% Completed | 14m 12s
# Local Minima of loss reached.
# Processing Batch:  34
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7114059.589996853
# Epoch:  1
# [########################################] | 100% Completed | 14m 15s
# Local Minima of loss reached.
# Processing Batch:  35
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7130876.169996831
# Epoch:  1
# [########################################] | 100% Completed | 14m 25s
# Local Minima of loss reached.
# Processing Batch:  36
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7141036.5999968145
# Epoch:  1
# [########################################] | 100% Completed | 14m 23s
# Local Minima of loss reached.
# Processing Batch:  37
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7165894.879996767
# Epoch:  1
# [########################################] | 100% Completed | 14m 21s
# Local Minima of loss reached.
# Processing Batch:  38
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7176622.29999676
# Epoch:  1
# [########################################] | 100% Completed | 14m 24s
# Local Minima of loss reached.
# Processing Batch:  39
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7240133.509996677
# Epoch:  1
# [########################################] | 100% Completed | 14m 34s
# Local Minima of loss reached.
# Processing Batch:  40
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7264607.4099966325
# Epoch:  1
# [########################################] | 100% Completed | 14m 44s
# Local Minima of loss reached.
# Processing Batch:  41
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7352985.849996502
# Epoch:  1
# [########################################] | 100% Completed | 14m 42s
# Local Minima of loss reached.
# Processing Batch:  42
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7341703.119996533
# Epoch:  1
# [########################################] | 100% Completed | 14m 52s
# Transition Made:  [16 15]
# Current Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7339608.119996534
# Epoch:  2
# [########################################] | 100% Completed | 14m 47s
# Local Minima of loss reached.
# Processing Batch:  43
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7361675.969996484
# Epoch:  1
# [########################################] | 100% Completed | 14m 47s
# Local Minima of loss reached.
# Processing Batch:  44
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7460542.409996344
# Epoch:  1
# [########################################] | 100% Completed | 15m 10s
# Local Minima of loss reached.
# Processing Batch:  45
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7497414.289996302
# Epoch:  1
# [########################################] | 100% Completed | 15m 5ss
# Local Minima of loss reached.
# Processing Batch:  46
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7485594.389996315
# Epoch:  1
# [########################################] | 100% Completed | 15m 3ss
# Local Minima of loss reached.
# Processing Batch:  47
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7487846.449996306
# Epoch:  1
# [########################################] | 100% Completed | 15m 9ss
# Local Minima of loss reached.
# Processing Batch:  48
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7477768.349996309
# Epoch:  1
# [########################################] | 100% Completed | 14m 54s
# Local Minima of loss reached.
# Processing Batch:  49
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7503426.299996287
# Epoch:  1
# [########################################] | 100% Completed | 15m 0ss
# Local Minima of loss reached.
# Processing Batch:  50
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7547639.369996222
# Epoch:  1
# [########################################] | 100% Completed | 15m 12s
# Local Minima of loss reached.
# Processing Batch:  51
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7574394.299996183
# Epoch:  1
# [########################################] | 100% Completed | 15m 13s
# Local Minima of loss reached.
# Processing Batch:  52
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7641452.249996081
# Epoch:  1
# [########################################] | 100% Completed | 15m 23s
# Local Minima of loss reached.
# Processing Batch:  53
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7644222.689996078
# Epoch:  1
# [########################################] | 100% Completed | 15m 32s
# Local Minima of loss reached.
# Processing Batch:  54
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7689669.259996012
# Epoch:  1
# [########################################] | 100% Completed | 15m 47s
# Local Minima of loss reached.
# Processing Batch:  55
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7691935.0199959995
# Epoch:  1
# [########################################] | 100% Completed | 15m 28s
# Local Minima of loss reached.
# Processing Batch:  56
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7677316.639996028
# Epoch:  1
# [########################################] | 100% Completed | 15m 27s
# Local Minima of loss reached.
# Processing Batch:  57
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7722666.189995959
# Epoch:  1
# [########################################] | 100% Completed | 15m 41s
# Local Minima of loss reached.
# Processing Batch:  58
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7753135.229995921
# Epoch:  1
# [########################################] | 100% Completed | 15m 47s
# Local Minima of loss reached.
# Processing Batch:  59
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7833560.969995795
# Epoch:  1
# [########################################] | 100% Completed | 15m 53s
# Local Minima of loss reached.
# Processing Batch:  60
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7956490.8699956285
# Epoch:  1
# [########################################] | 100% Completed | 16m 12s
# Local Minima of loss reached.
# Processing Batch:  61
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8048544.179995479
# Epoch:  1
# [########################################] | 100% Completed | 16m 23s
# Local Minima of loss reached.
# Processing Batch:  62
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8032599.749995507
# Epoch:  1
# [########################################] | 100% Completed | 16m 9ss
# Local Minima of loss reached.
# Processing Batch:  63
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8023257.3199955225
# Epoch:  1
# [########################################] | 100% Completed | 16m 12s
# Local Minima of loss reached.
# Processing Batch:  64
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8068282.389995462
# Epoch:  1
# [########################################] | 100% Completed | 16m 11s
# Local Minima of loss reached.
# Processing Batch:  65
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8016785.479995539
# Epoch:  1
# [########################################] | 100% Completed | 16m 22s
# Local Minima of loss reached.
# Processing Batch:  66
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8096790.31999542
# Epoch:  1
# [########################################] | 100% Completed | 16m 49s
# Local Minima of loss reached.
# Processing Batch:  67
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8048174.429995479
# Epoch:  1
# [########################################] | 100% Completed | 16m 34s
# Local Minima of loss reached.
# Processing Batch:  68
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8104783.959995403
# Epoch:  1
# [########################################] | 100% Completed | 17m 19s
# Local Minima of loss reached.
# Processing Batch:  69
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8135927.899995355
# Epoch:  1
# [########################################] | 100% Completed | 17m 13s
# Local Minima of loss reached.
# Processing Batch:  70
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8125994.569995363
# Epoch:  1
# [########################################] | 100% Completed | 17m 21s
# Local Minima of loss reached.
# Processing Batch:  71
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8157558.779995332
# Epoch:  1
# [########################################] | 100% Completed | 17m 24s
# Local Minima of loss reached.
# Processing Batch:  72
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8116361.719995384
# Epoch:  1
# [########################################] | 100% Completed | 17m 23s
# Local Minima of loss reached.
# Processing Batch:  73
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8138287.909995344
# Epoch:  1
# [########################################] | 100% Completed | 16m 49s
# Local Minima of loss reached.
# Processing Batch:  74
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8160144.549995332
# Epoch:  1
# [########################################] | 100% Completed | 20m 29s
# Local Minima of loss reached.
# Processing Batch:  75
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8158562.819995331
# Epoch:  1
# [########################################] | 100% Completed | 17m 26s
# Local Minima of loss reached.
# Processing Batch:  76
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8179263.759995286
# Epoch:  1
# [########################################] | 100% Completed | 17m 55s
# Local Minima of loss reached.
# Processing Batch:  77
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8219199.659995249
# Epoch:  1
# [########################################] | 100% Completed | 17m 21s
# Local Minima of loss reached.
# Processing Batch:  78
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8210328.659995245
# Epoch:  1
# [########################################] | 100% Completed | 17m 22s
# Local Minima of loss reached.
# Processing Batch:  79
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8219508.899995232
# Epoch:  1
# [########################################] | 100% Completed | 17m 9ss
# Local Minima of loss reached.
# Processing Batch:  80
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8203612.789995267
# Epoch:  1
# [########################################] | 100% Completed | 17m 22s
# Local Minima of loss reached.
# Processing Batch:  81
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8122571.979995377
# Epoch:  1
# [########################################] | 100% Completed | 20m 16s
# Local Minima of loss reached.
# Processing Batch:  82
# Initial Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 's', 'r', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7485944.389996201
# Epoch:  1
# [########################################] | 100% Completed | 15m 55s
# Transition Made:  [16 15]
# Current Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'l', 'r', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7428401.389996255
# Epoch:  2
# [########################################] | 100% Completed | 13m 59s
# Transition Made:  [14 15]
# Current Key Config:
# ['u', 'g', 'd', 'm', 'q', 'z', 'h', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'l', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7423738.189996293
# Epoch:  3
# [########################################] | 100% Completed | 13m 51s
# Transition Made:  [3 6]
# Current Key Config:
# ['u', 'g', 'd', 'h', 'q', 'z', 'm', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'l', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7421316.789996311
# Epoch:  4
# [########################################] | 100% Completed | 14m 4ss
# Transition Made:  [ 3 15]
# Current Key Config:
# ['u', 'g', 'd', 'l', 'q', 'z', 'm', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7416287.819996361
# Epoch:  5
# [########################################] | 100% Completed | 14m 37s
# Transition Made:  [2 6]
# Current Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7412110.619996395
# Epoch:  6
# [########################################] | 100% Completed | 14m 42s
# Local Minima of loss reached.
# Processing Batch:  83
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7850982.329995945
# Epoch:  1
# [########################################] | 100% Completed | 15m 58s
# Transition Made:  [5 4]
# Current Key Config:
# ['u', 'g', 'm', 'l', 'z', 'q', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  7850780.429995945
# Epoch:  2
# [########################################] | 100% Completed | 15m 55s
# Local Minima of loss reached.
# Processing Batch:  84
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'z', 'q', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  8086237.459995576
# Epoch:  1
# [########################################] | 100% Completed | 15m 50s
# Local Minima of loss reached.
# Processing Batch:  85
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'z', 'q', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6744304.259997066
# Epoch:  1
# [########################################] | 100% Completed | 12m 38s
# Transition Made:  [5 4]
# Current Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  6742673.259997071
# Epoch:  2
# [########################################] | 100% Completed | 12m 27s
# Local Minima of loss reached.
# Processing Batch:  86
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  5517747.109998101
# Epoch:  1
# [########################################] | 100% Completed | 11m 49s
# Local Minima of loss reached.
# Processing Batch:  87
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  5763660.879997985
# Epoch:  1
# [########################################] | 100% Completed | 11m 59s
# Local Minima of loss reached.
# Processing Batch:  88
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  5538164.029998087
# Epoch:  1
# [########################################] | 100% Completed | 11m 20s
# Local Minima of loss reached.
# Processing Batch:  89
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  5580181.049998087
# Epoch:  1
# [########################################] | 100% Completed | 11m 7ss
# Local Minima of loss reached.
# Processing Batch:  90
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  4812863.359998494
# Epoch:  1
# [########################################] | 100% Completed | 572.90 s
# Local Minima of loss reached.
# Processing Batch:  91
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  4683124.789998525
# Epoch:  1
# [########################################] | 100% Completed | 578.68 s
# Local Minima of loss reached.
# Processing Batch:  92
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  4857972.059998477
# Epoch:  1
# [########################################] | 100% Completed | 563.27 s
# Local Minima of loss reached.
# Processing Batch:  93
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  4671862.789998548
# Epoch:  1
# [########################################] | 100% Completed | 576.20 s
# Local Minima of loss reached.
# Processing Batch:  94
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  4992174.319998417
# Epoch:  1
# [########################################] | 100% Completed | 10m 16s
# Local Minima of loss reached.
# Processing Batch:  95
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  4524865.609998596
# Epoch:  1
# [########################################] | 100% Completed | 560.35 s
# Local Minima of loss reached.
# Processing Batch:  96
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  4118955.089998779
# Epoch:  1
# [########################################] | 100% Completed | 495.16 s
# Transition Made:  [6 8]
# Current Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'f', 'p', 'd', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  4117849.289998781
# Epoch:  2
# [########################################] | 100% Completed | 500.36 s
# Transition Made:  [21 25]
# Current Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'f', 'p', 'd', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'v', 'w', 'j', 'x', 'b']
#
# Loss:  4116909.0899987826
# Epoch:  3
# [########################################] | 100% Completed | 510.39 s
# Local Minima of loss reached.
# Processing Batch:  97
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'f', 'p', 'd', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'v', 'w', 'j', 'x', 'b']
#
# Loss:  4215230.809998743
# Epoch:  1
# [########################################] | 100% Completed | 512.31 s
# Local Minima of loss reached.
# Processing Batch:  98
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'f', 'p', 'd', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'v', 'w', 'j', 'x', 'b']
#
# Loss:  4866856.4399983995
# Epoch:  1
# [########################################] | 100% Completed | 589.73 s
# Transition Made:  [6 8]
# Current Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'v', 'w', 'j', 'x', 'b']
#
# Loss:  4865106.239998406
# Epoch:  2
# [########################################] | 100% Completed | 10m 0ss
# Transition Made:  [21 25]
# Current Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  4863562.839998411
# Epoch:  3
# [########################################] | 100% Completed | 594.36 s
# Local Minima of loss reached.
# Processing Batch:  99
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  5523052.66999806
# Epoch:  1
# [########################################] | 100% Completed | 11m 18s
# Local Minima of loss reached.
# Processing Batch:  100
# Initial Key Config:
# ['u', 'g', 'm', 'l', 'q', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'k', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  4766564.31999848
# Epoch:  1
# [########################################] | 100% Completed | 569.57 s
# Transition Made:  [ 4 20]
# Current Key Config:
# ['u', 'g', 'm', 'l', 'k', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'q', 'b', 'w', 'j', 'x', 'v']
#
# Loss:  4761752.779998504
# Epoch:  2
# [########################################] | 100% Completed | 566.57 s
# Local Minima of loss reached.
# Final Key Config:
# ['u', 'g', 'm', 'l', 'k', 'z', 'd', 'p', 'f', 'c']
# ['e', 'o', 't', 'n', 'r', 'h', 's', 'i', 'a']
# ['y', 'q', 'b', 'w', 'j', 'x', 'v']
#
# Batch Minimized Loss:  691678765.0918331

# %%
# k2 = deepcopy(k)
# k2.slow_optimize_heuristic(dataset)
